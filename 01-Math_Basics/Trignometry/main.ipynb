# %%
import numpy as np
import matplotlib.pyplot as plt


nums = np.random.rand(1000)
plt.plot(nums,"s")
plt.show()
plt.hist(nums)
# Out:
# (array([100., 100.,  95., 104.,  91., 109.,  94., 108.,  99., 100.]),
#  array([0.00138477, 0.10124544, 0.20110611, 0.30096678, 0.40082745,
#         0.50068812, 0.60054879, 0.70040946, 0.80027013, 0.9001308 ,
#         0.99999147]),
#  <BarContainer object of 10 artists>)
